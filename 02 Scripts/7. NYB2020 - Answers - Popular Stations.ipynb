# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries & dataset
# #### 2. Flags for Station uses
# #### 3. Querying low Station uses
# #### 4. Removing all Station ID's with less than 100 hires
# #### 5. Splitting out Unique Stations

# %% [markdown]
# ## 1. Import libraries & dataset

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os

# %%
#Ensuring that the graphs you create are displayed within the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
#Folder path into usable string
path = r'C:\Users\willm\Dropbox\1 Data Analytics Course\1 New York Citibike Hire'

# %%
#Import Hire Dataset
NYB2020_Stations = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'NYB2020merged.pkl'))

# %%
#Set Pandas to show all columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 2. Flags for Station uses

# %% [markdown]
# Still using the NYB2020merged.pkl from Script 1, as I would like ALL uses - including the long ones - to be used.

# %%
NYB2020_Stations.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start_station_id               start_station_name  start_station_latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# 2               -73.974498             259    South St & Whitehall St
# 3               -74.006180             490            8 Ave & W 33 St
# 4               -73.958014            3637    Fulton St & Waverly Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.714275             -73.989900   30326  Subscriber
# 1             40.665147             -73.976376   17105    Customer
# 2             40.701221             -74.012342   40177  Subscriber
# 3             40.751551             -73.993934   27690  Subscriber
# 4             40.683239             -73.965996   32583  Subscriber
#
#    birth_year  gender  start_hour start_date2  temp  rain_snow day_of_week  \
# 0        1992       1           0  2020-01-01     3        0.0   Wednesday
# 1        1969       1           0  2020-01-01     3        0.0   Wednesday
# 2        1963       1           0  2020-01-01     3        0.0   Wednesday
# 3        1980       1           0  2020-01-01     3        0.0   Wednesday
# 4        1982       1           0  2020-01-01     3        0.0   Wednesday
#
#    day_of_week_number    month  month_number  TripMins  age
# 0                   3  January             1      13.0   28
# 1                   3  January             1      26.0   51
# 2                   3  January             1      24.0   57
# 3                   3  January             1      10.0   40
# 4                   3  January             1      12.0   38

# %%
#Creating a new column to allow me to GroupBy the Station IDs columns
NYB2020_Stations['1col'] = "1"

# %%
NYB2020_Stations['1col'] = NYB2020_Stations['1col'].astype('int8')

# %%
#Creating a GroupBy to give total uses by each 'age' in a new column.
NYB2020_Stations["uses_StartStation"] = NYB2020_Stations.groupby("start_station_id")['1col'].transform("sum")

# %%
NYB2020_Stations["uses_EndStation"] = NYB2020_Stations.groupby("end_station_id")['1col'].transform("sum")

# %%
NYB2020_Stations[['start_station_id', 'uses_StartStation']].head(20)
# Out:
#     start_station_id  uses_StartStation
# 0                504            59142.0
# 1               3423            48873.0
# 2               3687            73560.0
# 3                346            38629.0
# 4                372             8071.0
# 5                394            28740.0
# 6               3093            33556.0
# 7                514            97415.0
# 8                274            21312.0
# 9                467            18195.0
# 10               504            59142.0
# 11              3374            52390.0
# 12               514            97415.0
# 13               536            40448.0
# 14               502            39244.0
# 15              3046             6928.0
# 16               514            97415.0
# 17              3709            45925.0
# 18              3349            40286.0
# 19               516            19817.0

# %% [markdown]
# Stations 514 shows up 3 times, with the same uses.

# %%
NYB2020_Stations[['end_station_id', 'uses_EndStation']].head(20)
# Out:
#     end_station_id  uses_EndStation
# 0              307          52211.0
# 1             3300          16094.0
# 2              259          31685.0
# 3              490          62776.0
# 4             3637          16257.0
# 5              478          62586.0
# 6             3668          15573.0
# 7              426         101767.0
# 8              416          13779.0
# 9             3368          17005.0
# 10             393          26097.0
# 11            3379          14350.0
# 12             405          45905.0
# 13             174          35672.0
# 14             296            666.0
# 15            3068           6580.0
# 16             405          45905.0
# 17             440          26037.0
# 18            3411          10950.0
# 19             367          30044.0

# %% [markdown]
# Station 405 shows up twice, with the same uses.

# %% [markdown]
# ## 3. Querying low Station uses

# %%
#Checking to see how many times Stations are used as a starting point - max and min
NYB2020_Stations['start_station_id'].value_counts(dropna = False, ascending=True)
# Out:
# 4332         1
# 4310         2
# 4328         3
# 3912         3
# 4306         6
#          ...
# 499      91856
# 514      97415
# 435      99191
# 426      99364
# 3141    100753
# Name: start_station_id, Length: 1213, dtype: int64

# %%
NYB2020_Stations['start_station_idSTR'] = NYB2020_Stations['start_station_id'].astype('str')

# %%
NYB2020_StartStation4332 = NYB2020_Stations[NYB2020_Stations['start_station_idSTR']=='4332']

# %%
NYB2020_StartStation4332.head()
# Out:
#           tripduration                 starttime                  stoptime  \
# 19504238           318  2020-12-31 20:17:25.1670  2020-12-31 20:22:43.9950
#
#           start_station_id     start_station_name  start_station_latitude  \
# 19504238              4332  Morris Ave & E 163 St                40.82723
#
#           start_station_longitude  end_station_id       end_station_name  \
# 19504238               -73.917656            4169  Morris Ave & E 171 St
#
#           end_station_latitude  end_station_longitude  bikeid    usertype  \
# 19504238              40.83899               -73.9109   48231  Subscriber
#
#           birth_year  gender  start_hour start_date2  temp  rain_snow  \
# 19504238        1984       2          20  2020-12-31     7        1.0
#
#          day_of_week  day_of_week_number     month  month_number  TripMins  \
# 19504238    Thursday                   4  December            12       5.0
#
#           age  1col  uses_StartStation  uses_EndStation start_station_idSTR
# 19504238   36     1                1.0             75.0                4332

# %% [markdown]
# <font color='blue'>First used on the last day of our data!</font>

# %%
NYB2020_StartStation4310 = NYB2020_Stations[NYB2020_Stations['start_station_idSTR']=='4310']

# %%
NYB2020_StartStation4310.head()
# Out:
#           tripduration                 starttime                  stoptime  \
# 19484524           342  2020-12-31 12:01:46.9430  2020-12-31 12:07:29.3590
# 19488691           264  2020-12-31 13:47:57.8940  2020-12-31 13:52:22.6310
#
#           start_station_id start_station_name  start_station_latitude  \
# 19484524              4310     24 St & 38 Ave               40.756351
# 19488691              4310     24 St & 38 Ave               40.756351
#
#           start_station_longitude  end_station_id end_station_name  \
# 19484524               -73.936515            3586   34 Ave & 13 St
# 19488691               -73.936515            3745   36 Ave & 31 St
#
#           end_station_latitude  end_station_longitude  bikeid    usertype  \
# 19484524             40.763875             -73.936485   46577  Subscriber
# 19488691             40.756513             -73.929575   48559  Subscriber
#
#           birth_year  gender  start_hour start_date2  temp  rain_snow  \
# 19484524        1986       1          12  2020-12-31     7        1.0
# 19488691        1985       1          13  2020-12-31     7        1.0
#
#          day_of_week  day_of_week_number     month  month_number  TripMins  \
# 19484524    Thursday                   4  December            12       6.0
# 19488691    Thursday                   4  December            12       4.0
#
#           age  1col  uses_StartStation  uses_EndStation start_station_idSTR
# 19484524   34     1                2.0           3354.0                4310
# 19488691   35     1                2.0          10599.0                4310

# %% [markdown]
# <font color='blue'>First used on the last day of our data!</font>

# %%
NYB2020_StartStation3912 = NYB2020_Stations[NYB2020_Stations['start_station_idSTR']=='3912']

# %%
NYB2020_StartStation3912.head()
# Out:
#          tripduration                 starttime                  stoptime  \
# 161165            278  2020-01-06 10:15:25.1070  2020-01-06 10:20:03.1980
# 214920            486  2020-01-07 14:31:17.8780  2020-01-07 14:39:24.1440
# 2551333          2063  2020-03-04 13:24:20.8520  2020-03-04 13:58:43.8620
#
#          start_station_id start_station_name  start_station_latitude  \
# 161165               3912        MTL-AOS-5.1                 40.7903
# 214920               3912        MTL-AOS-5.1                 40.7903
# 2551333              3912        MTL-AOS-5.1                 40.7903
#
#          start_station_longitude  end_station_id end_station_name  \
# 161165                  -73.9597            3912      MTL-AOS-5.1
# 214920                  -73.9597            3912      MTL-AOS-5.1
# 2551333                 -73.9597            3912      MTL-AOS-5.1
#
#          end_station_latitude  end_station_longitude  bikeid    usertype  \
# 161165                40.7903               -73.9597   37965  Subscriber
# 214920                40.7903               -73.9597   37965  Subscriber
# 2551333               40.7903               -73.9597   37965    Customer
#
#          birth_year  gender  start_hour start_date2  temp  rain_snow  \
# 161165         1996       1          10  2020-01-06     5        2.0
# 214920         1996       1          14  2020-01-07     5        0.0
# 2551333        1969       0          13  2020-03-04    11        0.0
#
#         day_of_week  day_of_week_number    month  month_number  TripMins  age  \
# 161165       Monday                   1  January             1       5.0   24
# 214920      Tuesday                   2  January             1       8.0   24
# 2551333   Wednesday                   3    March             3      34.0   51
#
#          1col  uses_StartStation  uses_EndStation start_station_idSTR
# 161165      1                3.0              3.0                3912
# 214920      1                3.0              3.0                3912
# 2551333     1                3.0              3.0                3912

# %% [markdown]
# <font color='blue'>MTL-AOS-5.1's Long and Lat put it in the middle of Central Park, and all 3 trips started and ended there.</font>

# %% [markdown]
# ## 4. Removing all Station ID's with less than 100 hires
# #### Most will be Bike Stations that were launched later in the year, so have not had the time to accrue hires like other stations.

# %%
NYB2020_Stations.info()

# %%
NYB2020_Stations['uses_StartStation'] = NYB2020_Stations['uses_StartStation'].astype('int64')

# %%
#Creating a new column to display one of two flags, depending on the age of the person hiring the bike
NYB2020_Stations.loc[NYB2020_Stations['uses_StartStation'] > 100, 'Over_100'] = 'Y'
NYB2020_Stations.loc[NYB2020_Stations['uses_StartStation'] <= 100, 'Over_100'] = 'N'

# %%
NYB2020_Stations[['start_station_id', 'uses_StartStation', 'Over_100']].head(20)
# Out:
#     start_station_id  uses_StartStation Over_100
# 0                504              59142        Y
# 1               3423              48873        Y
# 2               3687              73560        Y
# 3                346              38629        Y
# 4                372               8071        Y
# 5                394              28740        Y
# 6               3093              33556        Y
# 7                514              97415        Y
# 8                274              21312        Y
# 9                467              18195        Y
# 10               504              59142        Y
# 11              3374              52390        Y
# 12               514              97415        Y
# 13               536              40448        Y
# 14               502              39244        Y
# 15              3046               6928        Y
# 16               514              97415        Y
# 17              3709              45925        Y
# 18              3349              40286        Y
# 19               516              19817        Y

# %%
NYB2020_Stations['Over_100'].value_counts(dropna = False, ascending=True)
# Out:
# N        1000
# Y    19505857
# Name: Over_100, dtype: int64

# %%
NYB2020_Over100Uses = NYB2020_Stations[NYB2020_Stations['Over_100']=='Y']

# %% [markdown]
# ## 5. Splitting out Unique Stations

# %%
#Creating a subset of the unique Start Stations
NYB2020_StationsUniqueStarts = NYB2020_Over100Uses.drop_duplicates(subset = ["start_station_id"])

# %%
#Showing that each station only shows up once
NYB2020_StationsUniqueStarts['start_station_id'].value_counts(dropna = False, ascending=True)
# Out:
# 504     1
# 3404    1
# 3407    1
# 3105    1
# 278     1
#        ..
# 3359    1
# 3100    1
# 3780    1
# 3782    1
# 4280    1
# Name: start_station_id, Length: 1189, dtype: int64

# %%
NYB2020_StationsUniqueStarts.to_csv(os.path.join(path, '02 Data','Prepared Data', 'NYB2020_UsesByStation.csv'), index = False)
# Out:
#           tripduration                 starttime                  stoptime  \
# 19506837           148  2020-12-31 23:55:42.2030  2020-12-31 23:58:10.4400
# 19506838            76  2020-12-31 23:56:20.4840  2020-12-31 23:57:37.2340
# 19506839          1504  2020-12-31 23:56:28.5940  2021-01-01 00:21:33.2290
# 19506840           268  2020-12-31 23:56:35.5290  2021-01-01 00:01:03.8460
# 19506841           636  2020-12-31 23:56:52.5540  2021-01-01 00:07:28.8400
# 19506842          1124  2020-12-31 23:57:15.6080  2021-01-01 00:15:59.8620
# 19506843           369  2020-12-31 23:57:17.1180  2021-01-01 00:03:27.1140
# 19506844          1060  2020-12-31 23:57:23.8780  2021-01-01 00:15:04.4860
# 19506845           184  2020-12-31 23:57:33.1060  2021-01-01 00:00:37.6170
# 19506846          1970  2020-12-31 23:57:47.3580  2021-01-01 00:30:38.0560
# 19506847           519  2020-12-31 23:57:50.2000  2021-01-01 00:06:29.6850
# 19506848           733  2020-12-31 23:58:10.1570  2021-01-01 00:10:23.5950
# 19506849          1178  2020-12-31 23:58:14.1000  2021-01-01 00:17:52.3380
# 19506850          1344  2020-12-31 23:58:17.4800  2021-01-01 00:20:41.6070
# 19506851           589  2020-12-31 23:58:21.2620  2021-01-01 00:08:10.9220
# 19506852          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 19506853           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 19506854           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 19506855           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 19506856          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#           start_station_id                   start_station_name  \
# 19506837               464                      E 56 St & 3 Ave
# 19506838               312                Allen St & Stanton St
# 19506839              3628                 Lenox Ave & W 117 St
# 19506840              4099               E 169 St & Webster Ave
# 19506841              3143                      5 Ave & E 78 St
# 19506842               490                      8 Ave & W 33 St
# 19506843              3288                      E 88 St & 1 Ave
# 19506844              3977          Prospect Ave & Longwood Ave
# 19506845               372            Franklin Ave & Myrtle Ave
# 19506846              3169               Riverside Dr & W 82 St
# 19506847               265             Stanton St & Chrystie St
# 19506848              3143                      5 Ave & E 78 St
# 19506849              3335                     Union St & 4 Ave
# 19506850               456                E 53 St & Madison Ave
# 19506851              3999  Adam Clayton Powell Blvd & W 138 St
# 19506852               526                      E 33 St & 5 Ave
# 19506853              3307               West End Ave & W 94 St
# 19506854              3510  Adam Clayton Powell Blvd & W 123 St
# 19506855              4073          W 51 St & Rockefeller Plaza
# 19506856              3581           Underhill Ave & Lincoln Pl
#
#           start_station_latitude  start_station_longitude  end_station_id  \
# 19506837               40.759345               -73.967597             456
# 19506838               40.722055               -73.989111             265
# 19506839               40.802557               -73.949078            3137
# 19506840               40.834015               -73.908863            4177
# 19506841               40.776321               -73.964274            3142
# 19506842               40.751551               -73.993934             490
# 19506843               40.778301               -73.948813            3282
# 19506844               40.818990               -73.902020            3977
# 19506845               40.694546               -73.958014             364
# 19506846               40.787209               -73.981281             529
# 19506847               40.722293               -73.991475             307
# 19506848               40.776321               -73.964274            3374
# 19506849               40.677274               -73.982820            3860
# 19506850               40.759711               -73.974023             468
# 19506851               40.816960               -73.942296            3518
# 19506852               40.747659               -73.984907            3614
# 19506853               40.794165               -73.974124            3383
# 19506854               40.807832               -73.949373            3518
# 19506855               40.759700               -73.978082             500
# 19506856               40.674012               -73.967146            3581
#
#                                        end_station_name  end_station_latitude  \
# 19506837                          E 53 St & Madison Ave             40.759711
# 19506838                       Stanton St & Chrystie St             40.722293
# 19506839                                5 Ave & E 72 St             40.772828
# 19506840                     Prospect Ave & Jennings St             40.831762
# 19506841                                1 Ave & E 62 St             40.761227
# 19506842                                8 Ave & W 33 St             40.751551
# 19506843                                5 Ave & E 88 St             40.783070
# 19506844                    Prospect Ave & Longwood Ave             40.818990
# 19506845                    Lafayette Ave & Classon Ave             40.689004
# 19506846                                W 42 St & 8 Ave             40.757570
# 19506847                          Canal St & Rutgers St             40.714275
# 19506848  Central Park North & Adam Clayton Powell Blvd             40.799484
# 19506849                       Wilson Ave & Troutman St             40.701660
# 19506850                             Broadway & W 56 St             40.765265
# 19506851                           Lenox Ave & W 126 St             40.808442
# 19506852                           Crescent St & 30 Ave             40.768692
# 19506853                      Cathedral Pkwy & Broadway             40.804213
# 19506854                           Lenox Ave & W 126 St             40.808442
# 19506855                             Broadway & W 51 St             40.762288
# 19506856                     Underhill Ave & Lincoln Pl             40.674012
#
#           end_station_longitude  bikeid    usertype  birth_year  gender  \
# 19506837             -73.974023   36946  Subscriber        1994       1
# 19506838             -73.991475   40896  Subscriber        1994       2
# 19506839             -73.966853   37804  Subscriber        1984       0
# 19506840             -73.896853   47843    Customer        1993       2
# 19506841             -73.960940   40691  Subscriber        1976       1
# 19506842             -73.993934   45654  Subscriber        1998       1
# 19506843             -73.959390   49620    Customer        1969       0
# 19506844             -73.902020   45758  Subscriber        1989       1
# 19506845             -73.960239   37243  Subscriber        1994       1
# 19506846             -73.990985   45168  Subscriber        2001       1
# 19506847             -73.989900   45215  Subscriber        1994       2
# 19506848             -73.955613   44238  Subscriber        1973       1
# 19506849             -73.927540   47991    Customer        1988       1
# 19506850             -73.981923   36946  Subscriber        1994       1
# 19506851             -73.945209   48973  Subscriber        1997       1
# 19506852             -73.924957   36467  Subscriber        1994       1
# 19506853             -73.966991   47749  Subscriber        1969       0
# 19506854             -73.945209   48691    Customer        1969       0
# 19506855             -73.983362   49564  Subscriber        1994       1
# 19506856             -73.967146   47364    Customer        1969       0
#
#           start_hour start_date2  temp  rain_snow day_of_week  \
# 19506837          23  2020-12-31     7        1.0    Thursday
# 19506838          23  2020-12-31     7        1.0    Thursday
# 19506839          23  2020-12-31     7        1.0    Thursday
# 19506840          23  2020-12-31     7        1.0    Thursday
# 19506841          23  2020-12-31     7        1.0    Thursday
# 19506842          23  2020-12-31     7        1.0    Thursday
# 19506843          23  2020-12-31     7        1.0    Thursday
# 19506844          23  2020-12-31     7        1.0    Thursday
# 19506845          23  2020-12-31     7        1.0    Thursday
# 19506846          23  2020-12-31     7        1.0    Thursday
# 19506847          23  2020-12-31     7        1.0    Thursday
# 19506848          23  2020-12-31     7        1.0    Thursday
# 19506849          23  2020-12-31     7        1.0    Thursday
# 19506850          23  2020-12-31     7        1.0    Thursday
# 19506851          23  2020-12-31     7        1.0    Thursday
# 19506852          23  2020-12-31     7        1.0    Thursday
# 19506853          23  2020-12-31     7        1.0    Thursday
# 19506854          23  2020-12-31     7        1.0    Thursday
# 19506855          23  2020-12-31     7        1.0    Thursday
# 19506856          23  2020-12-31     7        1.0    Thursday
#
#           day_of_week_number     month  month_number  TripMins  age  1col  \
# 19506837                   4  December            12       2.0   26     1
# 19506838                   4  December            12       1.0   26     1
# 19506839                   4  December            12      25.0   36     1
# 19506840                   4  December            12       4.0   27     1
# 19506841                   4  December            12      11.0   44     1
# 19506842                   4  December            12      19.0   22     1
# 19506843                   4  December            12       6.0   51     1
# 19506844                   4  December            12      18.0   31     1
# 19506845                   4  December            12       3.0   26     1
# 19506846                   4  December            12      33.0   19     1
# 19506847                   4  December            12       9.0   26     1
# 19506848                   4  December            12      12.0   47     1
# 19506849                   4  December            12      20.0   32     1
# 19506850                   4  December            12      22.0   26     1
# 19506851                   4  December            12      10.0   23     1
# 19506852                   4  December            12      34.0   26     1
# 19506853                   4  December            12       5.0   51     1
# 19506854                   4  December            12       3.0   51     1
# 19506855                   4  December            12      11.0   26     1
# 19506856                   4  December            12      43.0   51     1
#
#           uses_StartStation Over_100 YearQTRs
# 19506837              24827        Y        4
# 19506838              47053        Y        4
# 19506839              18901        Y        4
# 19506840               1494        Y        4
# 19506841              38750        Y        4
# 19506842              64669        Y        4
# 19506843              32563        Y        4
# 19506844               1320        Y        4
# 19506845               8071        Y        4
# 19506846              24405        Y        4
# 19506847              36245        Y        4
# 19506848              38750        Y        4
# 19506849              12912        Y        4
# 19506850              26452        Y        4
# 19506851               7778        Y        4
# 19506852              38555        Y        4
# 19506853              22756        Y        4
# 19506854              11309        Y        4
# 19506855               8172        Y        4
# 19506856              14743        Y        4

# %%
#Creating a subset of the unique End Stations
NYB2020_StationsUniqueEnds = NYB2020_Stations.drop_duplicates(subset = ["end_station_id"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19505857 entries, 0 to 19506856
# Data columns (total 29 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start_station_id         int16
#  4   start_station_name       object
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           int16
#  8   end_station_name         object
#  9   end_station_latitude     float64
#  10  end_station_longitude    float64
#  11  bikeid                   int32
#  12  usertype                 object
#  13  birth_year               int16
#  14  gender                   int8
#  15  start_hour               int8
#  16  start_date2              object
#  17  temp                     int8
#  18  rain_snow                float16
#  19  day_of_week              object
#  20  day_of_week_number       int8
#  21  month                    object
#  22  month_number             int8
#  23  TripMins                 float64
#  24  age                      int16
#  25  1col                     int8
#  26  uses_StartStation        int64
#  27  Over_100                 object
#  28  YearQTRs                 object
# dtypes: float16(1), float64(5), int16(4), int32(1), int64(2), int8(6), object(10)
# memory usage: 3.0+ GB

# %%
NYB2020_StationsUniqueEnds.to_csv(os.path.join(path, '02 Data','Prepared Data', 'NYB2020_UniqueEnds.csv'), index = False)
