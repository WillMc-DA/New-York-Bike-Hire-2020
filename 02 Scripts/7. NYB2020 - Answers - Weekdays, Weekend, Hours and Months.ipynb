# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries & dataset
# #### 2. Creating a Weekday/Weekend flag
# #### 3. Uses by date

# %% [markdown]
# ## 1. Import libraries & dataset

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os

# %%
#Ensuring that the graphs are displayed within the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
#Folder path into usable string
path = r'C:\Users\willm\Dropbox\1 Data Analytics Course\1 New York Citibike Hire'

# %%
#Set Pandas to show all columns
pd.set_option("display.max_columns", None)

# %%
#Import Hire Dataset
NYB2020_DaysOfTheWeek = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'NYB2020_1day_Script2.pkl'))

# %% [markdown]
# ## 2. Creating a Weekday/Weekend flag

# %%
NYB2020_DaysOfTheWeek.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19487603 entries, 0 to 19506856
# Data columns (total 30 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start_station_id         int16
#  4   start_station_name       object
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           int16
#  8   end_station_name         object
#  9   end_station_latitude     float64
#  10  end_station_longitude    float64
#  11  bikeid                   int32
#  12  usertype                 object
#  13  birth_year               int16
#  14  gender                   int8
#  15  start_hour               int8
#  16  start_date2              object
#  17  temp                     int8
#  18  rain_snow                float16
#  19  day_of_week              object
# ...

# %%
#Creating a new column to display one of two flags, depending on the day of hire
NYB2020_DaysOfTheWeek.loc[(NYB2020_DaysOfTheWeek['day_of_week_number'] > 5) & (NYB2020_DaysOfTheWeek['day_of_week_number'] <= 7), 'Week_Day_End'] = 'Weekend'
NYB2020_DaysOfTheWeek.loc[(NYB2020_DaysOfTheWeek['day_of_week_number'] >= 1) & (NYB2020_DaysOfTheWeek['day_of_week_number'] <= 5), 'Week_Day_End'] = 'Weekday'

# %%
NYB2020_DaysOfTheWeek['day_of_week'].value_counts(dropna = False, ascending=True)
# Out:
# Monday       2545841
# Friday       2677515
# Thursday     2694594
# Tuesday      2796335
# Wednesday    2825446
# Sunday       2862052
# Saturday     3085820
# Name: day_of_week, dtype: int64

# %% [markdown]
# <b>I used the above data for my Hires by Hours and Months slide in Tableau.</b>

# %%
NYB2020_DaysOfTheWeek['Week_Day_End'].value_counts(dropna = False, ascending=True)
# Out:
# Weekend     5947872
# Weekday    13539731
# Name: Week_Day_End, dtype: int64

# %%
NYB2020_DaysOfTheWeek.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start_station_id               start_station_name  start_station_latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start_station_longitude  end_station_id           end_station_name  \
# ...

# %% [markdown]
# ## 3. Uses by date

# %%
#Set Pandas to show all Rows
pd.set_option("display.max_rows", None)

# %%
NYB2020_DaysOfTheWeek['start_hourSTR'] = NYB2020_DaysOfTheWeek['start_hour'].astype('str')

# %%
NYB2020_DaysOfTheWeek["date_hour"] = NYB2020_DaysOfTheWeek.start_date2.str.cat(others=[NYB2020_DaysOfTheWeek.start_hourSTR], sep=', ')
NYB2020_DaysOfTheWeek
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
NYB2020_DaysOfTheWeek['date_hour'].value_counts(dropna = False, ascending=True)
# Out:
# 2020-06-04, 19        1
# 2020-06-06, 21        1
# 2020-06-07, 4         3
# 2020-06-06, 4         3
# 2020-06-03, 4         3
# 2020-06-03, 19        4
# 2020-06-02, 4         4
# 2020-06-05, 4         7
# 2020-06-04, 18        7
# 2020-06-04, 4         8
# 2020-03-19, 3        10
# 2020-03-19, 4        10
# 2020-03-29, 4        11
# 2020-04-06, 3        12
# 2020-06-02, 20       13
# 2020-04-08, 4        13
# 2020-03-20, 3        14
# 2020-03-23, 3        14
# 2020-03-19, 2        14
# 2020-04-24, 1        17
# 2020-12-25, 4        17
# 2020-04-13, 4        17
# 2020-04-17, 3        18
# 2020-04-27, 3        18
# 2020-03-26, 3        18
# 2020-04-08, 3        18
# 2020-12-18, 2        18
# 2020-04-13, 2        18
# 2020-04-13, 3        19
# 2020-03-24, 3        19
# 2020-03-23, 2        20
# 2020-03-25, 3        20
# 2020-04-24, 3        21
# 2020-04-18, 3        21
# 2020-04-22, 2        21
# 2020-04-22, 3        21
# 2020-04-02, 3        21
# 2020-04-03, 3        21
# ...

# %%
#Resetting 'show all rows' function
pd.reset_option('display.max_rows')

# %% [markdown]
# <font color="blue"> <b>Using the data from the last query above, I copied it and put it into Excel, imputing the Weekend/Weekday into a new column.</b></font>
